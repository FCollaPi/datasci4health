# %% [markdown]
# # Data exploration
#
# This notebooks is used to explore provided data and discovering interesting conditions to work with.
#
# First, we imported libraries used:

# %%
from sqlite3 import connect
import numpy as np
import pandas as pd
import os
import re

# %% [markdown]
# Then, we opened the tables relevant to our studies (Patients, Encounters, Conditions and Procedures)

# %%
conditions_path = '../data/raw/synthea/scenario1/conditions.csv'
encounters_path = '../data/raw/synthea/scenario1/encounters.csv'
patients_path = '../data/raw/synthea/scenario1/patients.csv'
procedures_path = '../data/raw/synthea/scenario1/procedures.csv'

# %%
conn = connect(':memory:')

# %% [markdown]
# The first rows of the Patients table can be seen below. It contains personal data of the synthetic patient, including birth and death dates, which will be used to infer death prognostics. Also, it can be seen that scenario1 presents a total of 1174 patients.

# %%
patients_df = pd.read_csv(patients_path)
patients_df.to_sql('patients', conn, if_exists='replace')
patients_df
# Out:
#                                         Id   BIRTHDATE   DEATHDATE  \
# 0     7b3c738d-3f86-58e3-450e-4018521d192f  2021-08-11         NaN
# 1     c40c2c75-13c9-8e4a-047f-573ae1330157  2020-03-03         NaN
# 2     39e76039-522c-61f1-d961-e03dce5f0bb2  1998-11-21  2003-07-17
# 3     ff981e00-4004-44b4-48ba-0bfa62440bb3  2009-07-29         NaN
# 4     648dbf91-4334-a7e2-2cfe-72e88dbd4c15  2000-12-04         NaN
# ...                                    ...         ...         ...
# 1169  c815ffa4-2917-2c09-1569-e90d5a89eeb2  1933-05-23  1948-05-19
# 1170  b7fda58e-8eb1-a2d0-8fbf-57afefce34c6  1933-05-23  2003-12-13
# 1171  1b46a593-3b14-53dd-1d2b-b59866e09a18  1933-05-23  2021-08-23
# 1172  5eeeb1e8-73c4-f7fa-cbb6-be359624f38e  1933-05-23  1975-02-25
# 1173  87770b59-ee92-450f-57fb-53fc8a07a0ef  1933-05-23         NaN
#
#               SSN    DRIVERS    PASSPORT PREFIX         FIRST  \
# 0     999-71-7790        NaN         NaN    NaN   Svetlana462
# 1     999-49-5505        NaN         NaN    NaN    Rosalyn434
# 2     999-36-5991        NaN         NaN    NaN  Lashawnda573
# 3     999-39-5303        NaN         NaN    NaN    Ulysses632
# 4     999-77-8366  S99996514  X32384432X    Mr.       Tory770
# ...           ...        ...         ...    ...           ...
# 1169  999-84-8049        NaN         NaN    NaN       Olen518
# 1170  999-57-9348  S99975005  X56712306X    Mr.     Edward499
# 1171  999-98-9276  S99942794  X86239063X    Mr.    Antoine384
# 1172  999-47-8049  S99934661  X24881672X    Mr.      Britt177
# 1173  999-22-7793  S99972924  X22865231X    Mr.      Lloyd546
#
#                  LAST SUFFIX  ...                        BIRTHPLACE  \
# 0           O'Hara248    NaN  ...         Boston  Massachusetts  US
# 1     Christiansen251    NaN  ...       Lawrence  Massachusetts  US
# 2           Daniel959    NaN  ...  North Reading  Massachusetts  US
# 3             Rice937    NaN  ...       Scituate  Massachusetts  US
# 4            Harvey63    NaN  ...         Boston  Massachusetts  US
# ...               ...    ...  ...                               ...
# 1169        Hammes673    NaN  ...      Arlington  Massachusetts  US
# 1170          Cole117    NaN  ...       Montague  Massachusetts  US
# 1171        Brekke496    NaN  ...        Andover  Massachusetts  US
# 1172   Breitenberg711    NaN  ...      Hopkinton  Massachusetts  US
# 1173         Stehr398    NaN  ...        Maynard  Massachusetts  US
#
#                           ADDRESS         CITY          STATE  \
# 0      971 Ullrich Grove Suite 53       Boston  Massachusetts
# 1         485 Senger Route Apt 34      Waltham  Massachusetts
# 2             944 Witting Passage      Everett  Massachusetts
# 3               414 Rempel Harbor     Cohasset  Massachusetts
# 4          368 Pouros Ramp Apt 46    Haverhill  Massachusetts
# ...                           ...          ...            ...
# 1169          541 Lakin Promenade  Northampton  Massachusetts
# 1170       498 Shields Trafficway  Northampton  Massachusetts
# 1171  1093 McClure Village Apt 71  Northampton  Massachusetts
# 1172        572 Sipes Ramp Apt 94  Northampton  Massachusetts
# 1173           968 Roberts Bypass  Northampton  Massachusetts
#
#                 COUNTY     ZIP        LAT        LON HEALTHCARE_EXPENSES  \
# 0       Suffolk County  2135.0  42.304260 -71.045262        2.295091e+04
# 1     Middlesex County  2451.0  42.340439 -71.206815        5.476973e+04
# 2     Middlesex County  2149.0  42.412900 -71.009282        1.391483e+05
# 3       Norfolk County     NaN  42.214770 -70.814553        3.393595e+05
# 4         Essex County  1832.0  42.779225 -71.055842        5.432674e+05
# ...                ...     ...        ...        ...                 ...
# 1169  Hampshire County  1053.0  42.284637 -72.589066        4.060467e+04
# 1170  Hampshire County     NaN  42.354777 -72.593976        1.164761e+06
# 1171  Hampshire County  1062.0  42.405194 -72.755758        5.698680e+05
# 1172  Hampshire County  1053.0  42.288684 -72.671682        1.087981e+05
# 1173  Hampshire County  1063.0  42.360350 -72.590618        3.252791e+05
#
#      HEALTHCARE_COVERAGE
# 0                 0.0000
# 1              2624.1225
# 2               932.7450
# 3                90.6000
# 4              2173.6425
# ...                  ...
# 1169           7632.8415
# 1170         163012.4570
# 1171         151240.1710
# 1172         128412.6970
# 1173         138746.5215
#
# [1174 rows x 25 columns]

# %% [markdown]
# The next seen table is the Conditions table. It contains the synthetic description of the conditions of a patient as well as the standardized code of that condition, for each encounter (a period that a patient enters the medical care unit, either for emergency or consultation). Those can also be interesting as variables for prognostic inference.

# %%
conds_df = pd.read_csv(conditions_path)
conds_df.to_sql('conditions', conn, if_exists='replace')
conds_df.head()
# Out:
#         START        STOP                               PATIENT  \
# 0  2021-12-26  2022-01-07  c40c2c75-13c9-8e4a-047f-573ae1330157
# 1  1999-05-12         NaN  39e76039-522c-61f1-d961-e03dce5f0bb2
# 2  1999-05-12         NaN  39e76039-522c-61f1-d961-e03dce5f0bb2
# 3  2003-03-04  2003-03-17  39e76039-522c-61f1-d961-e03dce5f0bb2
# 4  2003-07-17         NaN  39e76039-522c-61f1-d961-e03dce5f0bb2
#
#                               ENCOUNTER       CODE  \
# 0  862287d1-a2eb-8116-de42-e76de6163260  195662009
# 1  00681d7e-e9bb-392b-6ccb-209cf46e2ec3  128613002
# 2  00681d7e-e9bb-392b-6ccb-209cf46e2ec3  703151001
# 3  7ac71954-b14b-f259-f032-bc07d5f4eaa6   43878008
# 4  705cabcc-6c94-1804-ee22-0e0b944ed62f  262574004
#
#                              DESCRIPTION
# 0     Acute viral pharyngitis (disorder)
# 1                       Seizure disorder
# 2  History of single seizure (situation)
# 3   Streptococcal sore throat (disorder)
# 4                           Bullet wound

# %% [markdown]
# We save here the counts of each condition in this scenario table for visualization, in the file `conditions_type_counts.csv`

# %%
conds_df[['CODE', 'DESCRIPTION']].value_counts().to_csv('../data/interim/scenario1/conditions_type_counts.csv')

# %% [markdown]
# Upon visualizing the above file, we could extract some sets of conditions we found interesting.
#
# The first set we explored was the licit and illicit drug abuse, namely the conditions including the words `drug`, `alcohol`, `opioid` and `tobacco`. From that, we found a total of 356 conditions.

# %%
pd.read_sql(
    '''
    SELECT * FROM conditions
    WHERE DESCRIPTION LIKE '%drug%' OR DESCRIPTION LIKE '%alcohol%' OR DESCRIPTION LIKE '%opioid%' OR DESCRIPTION LIKE '%tobacco%'
    '''
    , conn
)
# Out:
#      index       START        STOP                               PATIENT  \
# 0      238  1997-06-03  1999-06-15  04e9ac90-2279-d293-523f-838b39d1e177
# 1      292  2020-09-22  2021-09-28  5f2e1751-1689-2b18-f3df-1cf4a05b5439
# 2      711  2002-12-27  2014-02-14  53b07e50-426d-43bb-42d9-d175c2fb29f6
# 3      766  2022-04-01        None  53b07e50-426d-43bb-42d9-d175c2fb29f6
# 4      789  2021-11-26        None  ea3c8180-450a-de48-559b-9d753d346507
# ..     ...         ...         ...                                   ...
# 351  36139  1952-06-30        None  c20cd05e-a058-b63b-aa3d-38325afdd690
# 352  36140  1952-06-30        None  c20cd05e-a058-b63b-aa3d-38325afdd690
# 353  36241  2005-09-27  2009-10-20  2fd7bfe7-8c26-8be1-b074-efd95829f978
# 354  36285  1995-08-01  1997-08-12  b7fda58e-8eb1-a2d0-8fbf-57afefce34c6
# 355  36356  1966-10-11  1967-10-17  5eeeb1e8-73c4-f7fa-cbb6-be359624f38e
#
#                                 ENCOUNTER               CODE  \
# 0    20917154-d6c5-6c59-6532-26aecd1165aa  10939881000119104
# 1    e7d4fd73-34ae-a5f3-16a5-4c9ee897f8e9  10939881000119104
# 2    2b6ffb87-d675-a040-17e4-61d4a385af70          361055000
# 3    7fc3b70a-fbb7-1b7d-6cc1-8ccf00a2da18  10939881000119104
# 4    3d40b5e1-2b58-b08b-5142-0dcc98c1147c  10939881000119104
# ..                                    ...                ...
# 351  6b443522-a92c-286c-4058-61b0bfc5c488            5602001
# 352  6b443522-a92c-286c-4058-61b0bfc5c488          449868002
# 353  c684d175-c5e0-da6d-5946-147ef37623a1  10939881000119104
# 354  051bc787-cf22-09b9-bc4e-3a6f86c877b6  10939881000119104
# 355  2766bb28-a7b1-5552-ddd9-0a94735e62d3          361055000
#
#                                        DESCRIPTION
# 0    Unhealthy alcohol drinking behavior (finding)
# 1    Unhealthy alcohol drinking behavior (finding)
# 2                          Misuses drugs (finding)
# 3    Unhealthy alcohol drinking behavior (finding)
# 4    Unhealthy alcohol drinking behavior (finding)
# ..                                             ...
# 351                        Opioid abuse (disorder)
# 352                           Smokes tobacco daily
# 353  Unhealthy alcohol drinking behavior (finding)
# 354  Unhealthy alcohol drinking behavior (finding)
# 355                        Misuses drugs (finding)
#
# [356 rows x 7 columns]

# %% [markdown]
# 38  e71f8daf-e525-adca-daa7-9205f42f58c5       424132000
#
#                                           DESCRIPTION
# 0                   Suspected lung cancer (situation)
# 1               Non-small cell lung cancer (disorder)
# 2   Non-small cell carcinoma of lung  TNM stage 1 ...
# 3                   Suspected lung cancer (situation)
# 4               Non-small cell lung cancer (disorder)
# 5   Non-small cell carcinoma of lung  TNM stage 1 ...
# 6                   Suspected lung cancer (situation)
# 7               Non-small cell lung cancer (disorder)
# 8   Non-small cell carcinoma of lung  TNM stage 1 ...
# 9                   Suspected lung cancer (situation)
# 10              Non-small cell lung cancer (disorder)
# 11  Non-small cell carcinoma of lung  TNM stage 1 ...
# 12                  Suspected lung cancer (situation)
# 13            Small cell carcinoma of lung (disorder)
# 14  Primary small cell malignant neoplasm of lung ...
# 15                  Suspected lung cancer (situation)
# 16              Non-small cell lung cancer (disorder)
# 17  Non-small cell carcinoma of lung  TNM stage 1 ...
# 18                  Suspected lung cancer (situation)
# 19            Small cell carcinoma of lung (disorder)
# 20  Primary small cell malignant neoplasm of lung ...
# 21                  Suspected lung cancer (situation)
# 22              Non-small cell lung cancer (disorder)
# 23  Non-small cell carcinoma of lung  TNM stage 1 ...
# 24                  Suspected lung cancer (situation)
# 25              Non-small cell lung cancer (disorder)
# 26  Non-small cell carcinoma of lung  TNM stage 1 ...
# 27                  Suspected lung cancer (situation)
# 28              Non-small cell lung cancer (disorder)
# 29  Non-small cell carcinoma of lung  TNM stage 1 ...
# 30                  Suspected lung cancer (situation)
# 31              Non-small cell lung cancer (disorder)
# 32  Non-small cell carcinoma of lung  TNM stage 1 ...
# 33                  Suspected lung cancer (situation)
# 34              Non-small cell lung cancer (disorder)
# 35  Non-small cell carcinoma of lung  TNM stage 1 ...
# 36                  Suspected lung cancer (situation)
# 37              Non-small cell lung cancer (disorder)
# 38  Non-small cell carcinoma of lung  TNM stage 1 ...

# %% [markdown]
# In this next step, the conditions related to drug abuse (show above, along with `overdose`), the ones related to home violence (`violence` and `partner` were found in the countings table to be keywords for those) and the ones related to anxiety (`anxiety`, `stress` and `depression`) were joined for each patient. In the case of `overdose`, `partner` and `violence`, instead of only setting flags, the countings of each condition for that patient were applied, since it was logic to assume that each occurence of said condition corresponded to an episode.

# %%
def match_substring(sub_str, s):
    return sub_str.lower() in s.lower()

conds_df['OPIOID'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('opioid', x))
conds_df['ALCOHOL'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('alcohol', x))
conds_df['MISUSE'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('misuse', x))
conds_df['OVERDOSE'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('overdose', x))
conds_df['TOBACCO'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('tobacco', x))
conds_df['VIOLENCE'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('violence', x))
conds_df['PARTNER'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('partner abuse', x))
conds_df['DEPRESSION'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('depression', x))
conds_df['ANXIETY'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('anxiety', x))
conds_df['STRESS'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('stress', x))

drug_conds_df = conds_df.sort_values(by='START').groupby('PATIENT').aggregate({
    'OPIOID': lambda x: np.sum(x)>0,
    'ALCOHOL': lambda x: np.sum(x)>0,
    'MISUSE': lambda x: np.sum(x)>0,
    'OVERDOSE': lambda x: np.sum(x),
    'TOBACCO': lambda x: np.sum(x)>0,
    'VIOLENCE': lambda x: np.sum(x),
    'PARTNER': lambda x: np.sum(x),
    'DEPRESSION': lambda x: np.sum(x)>0,
    'ANXIETY': lambda x: np.sum(x)>0,
    'STRESS': lambda x: np.sum(x)>0,
})
drug_conds_df.to_sql('drug_conditions', conn, if_exists='replace')
drug_conds_df
# Out:
#                                       OPIOID  ALCOHOL  MISUSE  OVERDOSE  \
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95   False    False   False         0
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb   False    False   False         0
# 00c2e638-e098-f9ff-3610-5af6f565616d   False    False   False         0
# 00fe47e4-40df-207e-e357-789d2aca44c1   False    False   False         0
# 014e204c-bd87-a7fd-0ee5-86296391a44d   False    False   False         0
# ...                                      ...      ...     ...       ...
# fdaa221b-c4ee-7609-2cfc-1f034b15b3ef   False    False   False         0
# fe0b3504-c5df-4691-055d-34ad7002a5d1   False    False   False         1
# ff34b909-0ce6-1d5e-6b6d-9b96c75f08bb   False    False   False         0
# ff981e00-4004-44b4-48ba-0bfa62440bb3   False    False   False         0
# ffb18140-91de-27cf-d030-e5e05b6ab528   False    False   False         0
#
#                                       TOBACCO  VIOLENCE  PARTNER  DEPRESSION  \
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95    False         0        0       False
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb    False         0        1       False
# 00c2e638-e098-f9ff-3610-5af6f565616d    False         0        0       False
# 00fe47e4-40df-207e-e357-789d2aca44c1    False         0        0       False
# 014e204c-bd87-a7fd-0ee5-86296391a44d    False         0        0       False
# ...                                       ...       ...      ...         ...
# fdaa221b-c4ee-7609-2cfc-1f034b15b3ef    False         0        0       False
# fe0b3504-c5df-4691-055d-34ad7002a5d1    False         0        1       False
# ff34b909-0ce6-1d5e-6b6d-9b96c75f08bb    False         2        2       False
# ff981e00-4004-44b4-48ba-0bfa62440bb3    False         0        0       False
# ffb18140-91de-27cf-d030-e5e05b6ab528    False         1        1       False
#
#                                       ANXIETY  STRESS
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95    False    True
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb    False    True
# 00c2e638-e098-f9ff-3610-5af6f565616d    False   False
# 00fe47e4-40df-207e-e357-789d2aca44c1    False    True
# 014e204c-bd87-a7fd-0ee5-86296391a44d    False    True
# ...                                       ...     ...
# fdaa221b-c4ee-7609-2cfc-1f034b15b3ef     True    True
# fe0b3504-c5df-4691-055d-34ad7002a5d1    False    True
# ff34b909-0ce6-1d5e-6b6d-9b96c75f08bb    False    True
# ff981e00-4004-44b4-48ba-0bfa62440bb3    False   False
# ffb18140-91de-27cf-d030-e5e05b6ab528    False    True
#
# [1140 rows x 10 columns]

# %% [markdown]
# After generating that table, the maximum value of each column was summed, so it could be seed a max of 7 occurences of violence related conditions and 10 of partner related conditions.

# %%
drug_conds_df.max(0)
# Out:
# OPIOID        True
# ALCOHOL       True
# MISUSE        True
# OVERDOSE         1
# TOBACCO       True
# VIOLENCE         7
# PARTNER         10
# DEPRESSION    True
# ANXIETY       True
# STRESS        True
# dtype: object

# %% [markdown]
# Also, the number of patients having any of that conditions is shown below. There are low countings of patients for `depression` conditions, but other conditions have high countings, like `stress`.

# %%
(drug_conds_df>0).sum(0)
# Out:
# OPIOID         20
# ALCOHOL       164
# MISUSE         82
# OVERDOSE       49
# TOBACCO         6
# VIOLENCE      347
# PARTNER       453
# DEPRESSION      5
# ANXIETY       111
# STRESS        881
# dtype: int64

# %% [markdown]
# The same was done for lung related conditions. Only 13 patients were found to have said conditions.

# %%
def match_substring(sub_str, s):
    return sub_str.lower() in s.lower()

conds_df['LUNG'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('lung', x))

lung_conds_df = conds_df.sort_values(by='START').groupby('PATIENT').aggregate({
    'LUNG': lambda x: np.sum(x)>0,
})
lung_conds_df.to_sql('lung_conditions', conn, if_exists='replace')
lung_conds_df.head()
# Out:
#                                        LUNG
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95  False
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb  False
# 00c2e638-e098-f9ff-3610-5af6f565616d  False
# 00fe47e4-40df-207e-e357-789d2aca44c1  False
# 014e204c-bd87-a7fd-0ee5-86296391a44d  False

# %%
lung_conds_df['LUNG'].sum()
# Out:
# 13

# %% [markdown]
# The same was done for heart related conditions, namely `Cardiac Arrest` and `Myocardial Infarction`. 47 conditions were found for the first case and 30 for the second.

# %%
def match_substring(sub_str, s):
    return sub_str.lower() in s.lower()

conds_df['ARREST'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('Cardiac Arrest', x))
conds_df['INFARCTION'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('Myocardial Infarction', x))

cardiac_conds_df = conds_df.sort_values(by='START').groupby('PATIENT').aggregate({
    'ARREST': lambda x: np.sum(x)>0,
    'INFARCTION': lambda x: np.sum(x)>0,
})
cardiac_conds_df.to_sql('cardiac_conditions', conn, if_exists='replace')
cardiac_conds_df.head()
# Out:
#                                       ARREST  INFARCTION
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95   False       False
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb   False       False
# 00c2e638-e098-f9ff-3610-5af6f565616d   False       False
# 00fe47e4-40df-207e-e357-789d2aca44c1   False       False
# 014e204c-bd87-a7fd-0ee5-86296391a44d   False       False

# %%
cardiac_conds_df.sum(0)
# Out:
# ARREST        47
# INFARCTION    30
# dtype: int64

# %% [markdown]
# For concussion related conditions, 92 patients were found.

# %%
def match_substring(sub_str, s):
    return sub_str.lower() in s.lower()

conds_df['CONCUSSION'] = conds_df['DESCRIPTION'].apply(lambda x: match_substring('concussion', x))

concussion_conds_df = conds_df.sort_values(by='START').groupby('PATIENT').aggregate({
    'CONCUSSION': lambda x: np.sum(x)>0,
})
concussion_conds_df.to_sql('concussion_conditions', conn, if_exists='replace')
concussion_conds_df.head()
# Out:
#                                       CONCUSSION
# PATIENT
# 0000c650-47ba-eaf7-c2e6-ee06774a3d95       False
# 009c30e1-5fa4-f50c-dfa5-bf3092116bbb       False
# 00c2e638-e098-f9ff-3610-5af6f565616d       False
# 00fe47e4-40df-207e-e357-789d2aca44c1       False
# 014e204c-bd87-a7fd-0ee5-86296391a44d       False

# %%
concussion_conds_df.sum(0)
# Out:
# CONCUSSION    92
# dtype: int64

# %% [markdown]
# The next step was to count the number of patients that had a registered death date along interest condition sets. For the stress/drug set, it was found that high rates of patients that suffered from home violence and stress died.

# %%
patient_drugs = pd.read_sql(
    '''
    SELECT p.Id, p.birthdate, p.deathdate, d.OPIOID, d.ALCOHOL, d.MISUSE, d.OVERDOSE, d.TOBACCO, d.VIOLENCE, d.PARTNER, d.DEPRESSION, d.ANXIETY, d.STRESS
    FROM patients p
    JOIN drug_conditions d on p.Id = d.patient
    ''',
    conn
)
patient_drugs[~pd.isna(patient_drugs['DEATHDATE'])].sum(0)
# Out:
# Id            39e76039-522c-61f1-d961-e03dce5f0bb20d679725-4...
# BIRTHDATE     1998-11-211973-04-201960-12-271973-04-201952-0...
# DEATHDATE     2003-07-172005-08-192000-06-212011-12-161955-0...
# OPIOID                                                        7
# ALCOHOL                                                      31
# MISUSE                                                       11
# OVERDOSE                                                     10
# TOBACCO                                                       2
# VIOLENCE                                                     88
# PARTNER                                                     158
# DEPRESSION                                                    0
# ANXIETY                                                      15
# STRESS                                                      128
# dtype: object

# %% [markdown]
# In other hand, only 13 patients died with lung cancer conditions.

# %%
patient_lungs = pd.read_sql(
    '''
    SELECT p.Id, p.birthdate, p.deathdate, l.LUNG
    FROM patients p
    JOIN lung_conditions l on p.Id = l.patient
    ''',
    conn
)
patient_lungs[~pd.isna(patient_lungs['DEATHDATE'])].sum(0)
# Out:
# Id           39e76039-522c-61f1-d961-e03dce5f0bb20d679725-4...
# BIRTHDATE    1998-11-211973-04-201960-12-271973-04-201952-0...
# DEATHDATE    2003-07-172005-08-192000-06-212011-12-161955-0...
# LUNG                                                        13
# dtype: object

# %% [markdown]
# Also, 15 patients that had cardiac arrest and 25 that had miocardic infarction have died.

# %%
patient_cardiacs = pd.read_sql(
    '''
    SELECT p.Id, p.birthdate, p.deathdate, l.ARREST, l.INFARCTION
    FROM patients p
    JOIN cardiac_conditions l on p.Id = l.patient
    ''',
    conn
)
patient_cardiacs[~pd.isna(patient_cardiacs['DEATHDATE'])].sum(0)
# Out:
# Id            39e76039-522c-61f1-d961-e03dce5f0bb20d679725-4...
# BIRTHDATE     1998-11-211973-04-201960-12-271973-04-201952-0...
# DEATHDATE     2003-07-172005-08-192000-06-212011-12-161955-0...
# ARREST                                                       15
# INFARCTION                                                   25
# dtype: object

# %% [markdown]
# It can also be seen that 14 patients that had a concussion died.

# %%
patient_concussions = pd.read_sql(
    '''
    SELECT p.Id, p.birthdate, p.deathdate, l.CONCUSSION
    FROM patients p
    JOIN concussion_conditions l on p.Id = l.patient
    ''',
    conn
)
patient_concussions[~pd.isna(patient_concussions['DEATHDATE'])].sum(0)
# Out:
# Id            39e76039-522c-61f1-d961-e03dce5f0bb20d679725-4...
# BIRTHDATE     1998-11-211973-04-201960-12-271973-04-201952-0...
# DEATHDATE     2003-07-172005-08-192000-06-212011-12-161955-0...
# CONCUSSION                                                   14
# dtype: object

# %%
patient_concussions = pd.read_sql(
    '''
    SELECT p.Id, p.birthdate, p.deathdate, c.DESCRIPTION, c.START
    FROM patients p
    JOIN conditions c on p.Id = c.patient
    ''',
    conn
)
patient_concussions[~pd.isna(patient_concussions['DEATHDATE'])].to_csv('../data/interim/scenario1/death_conditions.csv')
